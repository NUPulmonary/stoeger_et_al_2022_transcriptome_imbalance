# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['font.family'] = 'Arial'

# %%
import os
import random
import sys

src_dir = './../src/'
sys.path[0] = src_dir

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from copy import deepcopy
from scipy.stats import spearmanr


from access_biology_data import meta
from aging_tools import inout

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
sys.path.append('./../src/')
from aging_tools import inout, export
from access_aging_data import chaperome, earlier_studies, companions, sequencing
from access_biology_data import annotation, relations

# %% [markdown]
# # Construct sanity check: get median expression for every gene

# %%
# Get aging expression data, filter, and map to ncbi
df_counts, df_meta, df_genes = sequencing.load_cached_aging_map(
    dataset_name='aging_map_tmm_180105',
    unambiguous_to_entrez=True,
    as_entrez=True
)

# %%
# %%time
agg = []
for pfu in df_meta['pfu'].unique():
    f_pfu = df_meta['pfu']==pfu
    for tissue in df_meta['tissue'].unique():
        f_tissue = df_meta['tissue']==tissue
        for age in df_meta['age'].unique():
            f_age = df_meta['age']==age
            f = f_pfu & f_tissue & f_age
            
            if any(f):
                d = df_counts.loc[:, f]
                d = d.median(1).to_frame('median')
                d.loc[:, 'tissue'] = tissue
                d.loc[:, 'pfu'] = pfu
                d.loc[:, 'age'] = age
                d = d.reset_index()

                agg.append(d)
                
df_median_counts = pd.concat(agg)
# Out:
# CPU times: user 1.07 s, sys: 140 ms, total: 1.21 s
# Wall time: 1.22 s

# %%
import glob

# %%
agg = []

for batch in [1, 2, 3, 4, 5, 6]:
    p = inout.get_internal_path(
        'dynamic/tstoeger/181022_inclusive_any_detected_per_batch/{}/DE/Flu/*.csv'.format(int(batch)))
    d = glob.glob(p)

    files_to_process = pd.DataFrame(columns=['path'], data = d)
    files_to_process['base_name'] = files_to_process['path'].str.extract('.*/(.*).csv', expand=False)
    files_to_process[['tissue', 'pfu', 'dividend', 'divisor']] = files_to_process['base_name'].str.extract(
        '^(.*)_pfu_(.*)_ages_(.*) (.*)_DE', expand=False)
    files_to_process = files_to_process.set_index('base_name', verify_integrity=True)

    for j, v in files_to_process.iterrows():

        df = pd.read_csv(v['path'], usecols=['Symbol', 'log2FoldChange', 'pvalue', 'padj'])
        tags = ['tissue', 'pfu', 'dividend', 'divisor']
        for tag in tags:
            df.loc[:, tag] = v[tag]

        df.loc[:, 'batch'] = batch
            
        agg.append(df)

# %%
df = pd.concat(agg, axis=0)
df = df.rename(columns={'Symbol': 'gene_ensembl'})

for x in ['pfu', 'dividend', 'divisor']:
    df.loc[:, x] = df.loc[:, x].apply(float)

# %%
# Add ncbi gene IDs
df = pd.merge(
    df,
    df_genes[['gene_ensembl', 'gene_ncbi']], how='left').set_index('gene_ncbi').reset_index()

# %% [markdown]
# # Add some sanity checks and manually check discrepancies

# %%
df.loc[:, 'oldest'] = df.loc[:, ['dividend', 'divisor']].max(1)
df.loc[:, 'youngest'] = df.loc[:, ['dividend', 'divisor']].min(1)

# %%
for e in ['dividend', 'divisor', 'oldest', 'youngest']:
    df = pd.merge(
        df, 
        df_median_counts.rename(columns={'median': 'median_{}'.format(e)}), 
        left_on=['gene_ncbi', 'tissue', 'pfu', e],
        right_on=['gene_ncbi', 'tissue', 'pfu', 'age'],
        how='left'
    ).drop('age', 1)

# %%
f = df['dividend'] > df['divisor']

# %%
df.loc[f, 'o_over_y'] = df.loc[f, 'log2FoldChange']
df.loc[~f, 'o_over_y'] = -df.loc[~f, 'log2FoldChange']

# %%
test_dummy = df[(df['padj']<0.05) & ~(df['median_oldest'] == df['median_youngest'])]

# %%
f = test_dummy['median_oldest'] > test_dummy['median_youngest']
h = test_dummy[f]

# %%
h[h['o_over_y']<0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue     pfu
# AM         0.0       33
#            10.0      12
#            150.0     18
# AT2        0.0        4
#            10.0      63
#            150.0      7
# Adrenal    0.0       12
# BAT        0.0        7
# Blood      0.0        3
#            10.0       5
#            150.0     17
# Brain      0.0      130
# Esophagus  0.0        8
# Heart      0.0        1
# Kidney     0.0       23
# LI         0.0        3
# Liver      0.0        1
# Lung       0.0       66
#            10.0      10
# MoDC       0.0        1
#            10.0       1
#            150.0      5
# MuscSat    0.0        8
# SI         0.0        2
# Skin       0.0      124
# Stomach    0.0        2
# WAT        0.0        2
# dtype: int64

# %%
h[h['o_over_y']>0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue      pfu
# AM          0.0       535
#             10.0      125
#             150.0     417
# AT2         0.0       551
#             10.0     1006
#             150.0     344
# Adrenal     0.0      1650
# BAT         0.0      1307
# Blood       0.0       340
#             10.0     1033
#             150.0     704
# Brain       0.0       621
# Cerebellum  0.0       102
# Esophagus   0.0       744
# GutEP       0.0       247
# Heart       0.0       118
# Kidney      0.0      5873
# LI          0.0      1809
# Liver       0.0        81
# Lung        0.0       706
#             10.0      501
#             150.0     212
# MoDC        0.0       280
#             10.0       55
#             150.0     359
# MuscSat     0.0       157
# SI          0.0       309
# Skin        0.0      1310
# Stomach     0.0      1474
# WAT         0.0       763
# dtype: int64

# %%
h[h['o_over_y']<0]
# Out:
#             gene_ncbi        gene_ensembl  log2FoldChange        pvalue  \
# 18370        213391.0  ENSMUSG00000042129       -0.466398  7.545895e-05
# 18378         72446.0  ENSMUSG00000032841       -0.898626  2.624856e-04
# 18385         71684.0  ENSMUSG00000036249       -1.210527  3.998168e-04
# 188939        11861.0  ENSMUSG00000047446       -0.606757  9.527012e-04
# 264016        69833.0  ENSMUSG00000033020       -8.195262  2.470531e-05
# 264019        71675.0  ENSMUSG00000042208       -8.066146  4.464556e-05
# 264022        12909.0  ENSMUSG00000025532       -8.195041  8.834433e-05
# 264023        12825.0  ENSMUSG00000026043       -1.207501  8.539539e-05
# 264032        70984.0  ENSMUSG00000031938       -7.791774  1.618390e-04
# 486942   -4.152234
# 630063   -1.123190
# 630067   -5.726461
# 630069   -0.844910
# 736164   -3.086503
# 777994   -1.383340
# 777996   -1.516893
# 778001   -1.128024
# 778003   -1.308888
# 778008   -0.804617
# 778011   -0.642513
# 825746   -0.797474
# 825766   -0.654809
# 1063048  -8.172279
# 1141750  -0.559744
# 1299425  -0.860361
# 1299646  -0.807677
# 1354551  -1.021114
# 1407556  -2.718670
# 1407722  -1.011296
# ...            ...
# 10013279 -1.134377
# 10013294 -0.670734
# 10013296 -0.670290
# 10013308 -0.557116
# 10013325 -0.775549
# 10013351 -1.767176
# 10013355 -1.767176
# 10013374 -0.907510
# 10013375 -0.907502
# 10013387 -3.828962
# 10013389 -0.602098
# 10013393 -0.831917
# 10080335 -1.416595
# 10151033 -1.446365
# 10201889 -0.624763
# 10201894 -0.615607
# 10499699 -0.798324
# 10499784 -0.834804
# 10499810 -1.807303
# 10499822 -0.805871
# 10499837 -0.476496
# 10499839 -0.896238
# 10499846 -0.550970
# 10499849 -1.142110
# 10499883 -1.450693
# 10499884 -2.959803
# 10582080 -0.549528
# 10582081 -0.540558
# 10582082 -0.483252
# 10582085 -0.510373
#
# [568 rows x 17 columns]

# %%
f = test_dummy['median_oldest'] < test_dummy['median_youngest']
h = test_dummy[f]

# %%
h[h['o_over_y']<0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue      pfu
# AM          0.0       304
#             10.0       70
#             150.0     295
# AT2         0.0       513
#             10.0      504
#             150.0     288
# Adrenal     0.0      1319
# BAT         0.0       743
# Blood       0.0       274
#             10.0      279
#             150.0     308
# Brain       0.0       516
# Cerebellum  0.0       234
# Esophagus   0.0       615
# GutEP       0.0       314
# Heart       0.0       159
# Kidney      0.0      4882
# LI          0.0      1499
# Liver       0.0        97
# Lung        0.0       909
#             10.0      234
#             150.0     250
# MoDC        0.0       324
#             10.0       54
#             150.0     460
# MuscSat     0.0        92
# SI          0.0       182
# Skin        0.0      1527
# Stomach     0.0       792
# WAT         0.0       755
# dtype: int64

# %%
h[h['o_over_y']>0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue     pfu
# AM         0.0       24
#            10.0      18
#            150.0     23
# AT2        10.0     237
#            150.0      6
# Adrenal    0.0        2
# BAT        0.0       22
# Blood      0.0        1
#            10.0      22
#            150.0     14
# Brain      0.0      287
# Esophagus  0.0        3
# Heart      0.0        4
# Kidney     0.0       36
# LI         0.0        2
# Liver      0.0        2
# Lung       0.0       20
#            10.0      25
#            150.0      5
# MoDC       0.0        7
#            10.0       2
#            150.0      2
# MuscSat    0.0       17
# Skin       0.0      175
# Stomach    0.0        3
# dtype: int64

# %% [markdown]
# # Finally: export

# %%
p = inout.get_internal_path('datasets/tstoeger/181024_pool_differential_expression_inclusive_any_detected_by_batch/age_groups.csv.gz')
inout.ensure_presence_of_directory(p)
df.to_csv(p, compression='gzip', index=False)
