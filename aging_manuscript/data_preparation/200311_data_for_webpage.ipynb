# %%
# %matplotlib inline 
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd

# %%
import sys
sys.path.append('./../src/')
from aging_tools import inout
from access_aging_data import sequencing

# %%
set_name = '181028_inclusive_tmm'  # TMM normalized per condition

# %%
df_counts, df_meta, df_genes = sequencing.load_cached_aging_map(
    set_name, 
    unambiguous_to_entrez=False, 
    as_entrez=False)

# %%
df_meta['tissue'].unique()
# Out:
# array(['AM', 'AT2', 'Adrenal', 'BAT', 'Blood', 'Brain', 'Cerebellum',
#        'Esophagus', 'GutEP', 'Heart', 'Kidney', 'LI', 'Liver', 'Lung',
#        'MoDC', 'MuscSat', 'SI', 'Skin', 'Stomach', 'WAT'], dtype=object)

# %%
allowed = pd.DataFrame(
    [
    ('Adrenal', 0) ,
    ('BAT',  0) ,
    ('Blood',  0) ,
    ('Brain',  0),
    ('Cerebellum', 0) ,
    ('Esophagus',  0) ,
    ('GutEP',  0) ,
    ('Heart',  0) ,
    ('Kidney',  0) ,
    ('LI',  0) ,
    ('Liver',  0) ,
    ('Lung', 0) ,
    ('Lung', 150) ,
    ('MuscSat',  0) ,
    ('SI',  0) ,
    ('Skin',  0) ,
    ('Stomach',  0) ,
    ('WAT', 0)
        
    ],
    columns=['tissue', 'pfu']

)

# %%
df_meta = pd.merge(df_meta.reset_index(), allowed)

# %%
df_meta = df_meta.set_index('index')

# %%
renamer = {
    'Adrenal': 'Adrenal Gland', 
    'BAT': 'Brown adipose tissue', 
    'Blood': 'Blood', 
    'Brain': 'Frontal cortex', 
    'Esophagus': 'Esophagus', 
    'GutEP': 'Gut epithelium', 
    'Heart': 'Heart',
    'Kidney': 'Kidney', 
    'LI': 'Large intestine', 
    'Liver': 'Liver', 
    'Lung': 'Lung', 
    'MuscSat': 'Muscle', 
    'SI': 'Small intestine', 
    'Skin': 'Skin',
    'Stomach': 'Stomach', 
    'WAT': 'White adipose tissue', 
    'Cerebellum': 'Cerebellum'}

# %%
df_meta['tissue'] = df_meta['tissue'].replace(renamer)

# %%
df_counts = df_counts.reindex(columns=df_meta.index)

# %%
df_counts.columns.name = ''

# %%
df_meta.index.name = ''

# %%
df_counts.head()
# Out:
#                     M01_Adrenal_24M_F0_1  M02_Adrenal_24M_F0_2  \
# gene_ensembl
# ENSMUSG00000000001             75.819859              6.553441
# ENSMUSG00000000003              0.125530              0.145632
# ENSMUSG00000000028             78.958099             35.825478
# ENSMUSG00000000031             67.409378             64.951882
# ENSMUSG00000000037              0.125530              9.029185
#
#                     M03_Adrenal_24M_F0_3  M04_Adrenal_18M_F0_1  \
# gene_ensembl
# ENSMUSG00000000001              2.733760             19.688101
# ENSMUSG00000000003              0.130179              0.131254
# ENSMUSG00000000028             33.716374             23.231959
# ENSMUSG00000000031             78.497967             89.777740
# ENSMUSG00000000037             62.876481              8.137748
#
#                     M05_Adrenal_18M_F0_2  M06_Adrenal_18M_F0_3  \
# gene_ensembl
# ENSMUSG00000000001             19.080494              9.460485
# ENSMUSG00000000003              0.125530              0.139125
# ENSMUSG00000000028             37.156752             37.285440
# ENSMUSG00000000031             37.156752             89.735481
# ENSMUSG00000000037              8.787070              9.043111
#
#                     M07_Adrenal_12M_F0_1  M08_Adrenal_12M_F0_2  \
# gene_ensembl
# ENSMUSG00000000001             10.795543             14.272635
# ENSMUSG00000000003              0.125530              0.137237
# ENSMUSG00000000028             24.101677             59.011857
# ENSMUSG00000000031              9.163658             36.093298
# ENSMUSG00000000037             65.903023              0.137237
#
#                     M09_Adrenal_12M_F0_3  M10_Adrenal_09M_F0_1  ...  \
# gene_ensembl                                                    ...
# ENSMUSG00000000001              1.219717             22.480682  ...
# ENSMUSG00000000003              0.135524              0.145037  ...
# ENSMUSG00000000028             86.193353             34.663762  ...
# ENSMUSG00000000031              0.135524             34.663762  ...
# ENSMUSG00000000037              8.266972              0.145037  ...
#
#                     M21_WAT_18M_F0_6  M22_WAT_12M_F0_4  M23_WAT_12M_F0_5  \
# gene_ensembl
# ENSMUSG00000000001        103.667386         79.019196         94.968025
# ENSMUSG00000000003          0.181237          0.181237          0.181237
# ENSMUSG00000000028         63.432841         52.921113         92.249475
# ENSMUSG00000000031          0.181237         67.601285          0.181237
# ENSMUSG00000000037          0.181237          0.181237          0.181237
#
#                     M24_WAT_12M_F0_6  M25_WAT_09M_F0_4  M26_WAT_09M_F0_5  \
# gene_ensembl
# ENSMUSG00000000001         93.155658         98.049049        102.217492
# ENSMUSG00000000003          0.181237          0.181237          0.181237
# ENSMUSG00000000028         53.283587         75.756936         30.266527
# ENSMUSG00000000031         77.569303          0.181237          0.181237
# ENSMUSG00000000037         11.055438          0.181237          0.181237
#
#                     M27_WAT_09M_F0_6  M28_WAT_04M_F0_4  M29_WAT_04M_F0_5  \
# gene_ensembl
# ENSMUSG00000000001         83.731350        104.392333        130.490416
# ENSMUSG00000000003          0.181237          0.181237          0.181237
# ENSMUSG00000000028         29.360344         95.874208        108.560777
# ENSMUSG00000000031         73.763332         76.844356         90.074634
# ENSMUSG00000000037          0.181237         76.844356        122.878475
#
#                     M30_WAT_04M_F0_6
# gene_ensembl
# ENSMUSG00000000001         39.147125
# ENSMUSG00000000003          0.181237
# ENSMUSG00000000028         61.258001
# ENSMUSG00000000031          0.181237
# ENSMUSG00000000037          0.181237
#
# [5 rows x 518 columns]

# %%
df_meta.head()
# Out:
#                        age age_unit  mouse_id  pfu  replicate_id  \
#
# M01_Adrenal_24M_F0_1  24.0        M       1.0  0.0           1.0
# M02_Adrenal_24M_F0_2  24.0        M       2.0  0.0           2.0
# M03_Adrenal_24M_F0_3  24.0        M       3.0  0.0           3.0
# M04_Adrenal_18M_F0_1  18.0        M       4.0  0.0           1.0
# M05_Adrenal_18M_F0_2  18.0        M       5.0  0.0           2.0
#
#                              tissue  is_specimen  \
#
# M01_Adrenal_24M_F0_1  Adrenal Gland         True
# M02_Adrenal_24M_F0_2  Adrenal Gland         True
# M03_Adrenal_24M_F0_3  Adrenal Gland         True
# M04_Adrenal_18M_F0_1  Adrenal Gland         True
# M05_Adrenal_18M_F0_2  Adrenal Gland         True
#
#                                              run_name harvest_date  \
#
# M01_Adrenal_24M_F0_1  170329_NB501488_0082_AH2VV5BGX2   2015-01-19
# M02_Adrenal_24M_F0_2  170329_NB501488_0082_AH2VV5BGX2   2015-01-19
# M03_Adrenal_24M_F0_3  170329_NB501488_0082_AH2VV5BGX2   2015-01-19
# M04_Adrenal_18M_F0_1  170329_NB501488_0082_AH2VV5BGX2   2015-01-19
# M05_Adrenal_18M_F0_2  170329_NB501488_0082_AH2VV5BGX2   2015-01-19
#
#                       experimental_batch clotted died_during_intubation  \
#
# M01_Adrenal_24M_F0_1                 1.0   False                  False
# M02_Adrenal_24M_F0_2                 1.0   False                  False
# M03_Adrenal_24M_F0_3                 1.0   False                  False
# M04_Adrenal_18M_F0_1                 1.0   False                  False
# M05_Adrenal_18M_F0_2                 1.0   False                  False
#
#                       tumor I7_Index_ID I5_Index_ID  run_id  \
#
# M01_Adrenal_24M_F0_1  False        D705        D503      82
# M02_Adrenal_24M_F0_2  False        D705        D504      82
# M03_Adrenal_24M_F0_3  False        D705        D505      82
# M04_Adrenal_18M_F0_1  False        D705        D506      82
# M05_Adrenal_18M_F0_2  False        D705        D507      82
#
#                           orig_sample_name
#
# M01_Adrenal_24M_F0_1  M01_Adrenal_24M_F0_1
# M02_Adrenal_24M_F0_2  M02_Adrenal_24M_F0_2
# M03_Adrenal_24M_F0_3  M03_Adrenal_24M_F0_3
# M04_Adrenal_18M_F0_1  M04_Adrenal_18M_F0_1
# M05_Adrenal_18M_F0_2  M05_Adrenal_18M_F0_2

# %%
df_genes.head()
# Out:
#          gene_ensembl    Chr      Start        End  Length Strand  gene_ncbi  \
# 0  ENSMUSG00000000001   chr3  108107280  108146146    3262      -    14679.0
# 1  ENSMUSG00000000003   chrX   77837901   77853623    1599      -    54192.0
# 2  ENSMUSG00000000028  chr16   18780447   18811987    4722      -    12544.0
# 3  ENSMUSG00000000031   chr7  142575529  142578143    6343      -    14955.0
# 4  ENSMUSG00000000037   chrX  161117193  161258213   23080      +   107815.0
#
#   symbol_ncbi    type_of_gene nomenclature_status  genes_with_same_ensembl  \
# 0       Gnai3  protein-coding                   O                      1.0
# 1        Pbsn  protein-coding                   O                      1.0
# 2       Cdc45  protein-coding                   O                      1.0
# 3         H19           ncRNA                   O                      1.0
# 4       Scml2  protein-coding                   O                      1.0
#
#    genbank_validated_rna_length  genbank_validated_rna_cg  \
# 0                        3294.0                  0.414693
# 1                           NaN                       NaN
# 2                        1972.5                  0.495172
# 3                           NaN                       NaN
# 4                        4791.0                  0.415127
#
#   has_validated_protein_coding_RNA has_publication  present_in_genbank_info
# 0                             True            True                     True
# 1                            False            True                     True
# 2                             True            True                     True
# 3                            False            True                     True
# 4                             True            True                     True

# %%
export_folder = inout.get_internal_path('datasets/general/webpage/v200311')
inout.ensure_presence_of_directory(export_folder)

# %%
df_counts.to_csv(
    os.path.join(
        export_folder,
        'df_counts.csv'
    )
)

# %%
df_meta.to_csv(
    os.path.join(
        export_folder,
        'df_meta.csv'
    )
)

# %%
df_genes.to_csv(
    os.path.join(
        export_folder,
        'df_genes.csv'
    ), index=False
)
