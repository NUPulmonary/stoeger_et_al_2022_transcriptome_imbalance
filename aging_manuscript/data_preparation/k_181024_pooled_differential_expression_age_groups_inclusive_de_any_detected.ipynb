# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['font.family'] = 'Arial'

# %%
import os
import random
import sys

src_dir = './../src/'
sys.path[0] = src_dir

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from copy import deepcopy
from scipy.stats import spearmanr


from access_biology_data import meta
from aging_tools import inout

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
sys.path.append('./../src/')
from aging_tools import inout, export
from access_aging_data import chaperome, earlier_studies, companions, sequencing
from access_biology_data import annotation, relations

# %% [markdown]
# # Construct sanity check: get median expression for every gene

# %%
# Get aging expression data, filter, and map to ncbi
df_counts, df_meta, df_genes = sequencing.load_cached_aging_map(
    dataset_name='aging_map_tmm_180105',
    unambiguous_to_entrez=True,
    as_entrez=True
)

# %%
# %%time
agg = []
for pfu in df_meta['pfu'].unique():
    f_pfu = df_meta['pfu']==pfu
    for tissue in df_meta['tissue'].unique():
        f_tissue = df_meta['tissue']==tissue
        for age in df_meta['age'].unique():
            f_age = df_meta['age']==age
            f = f_pfu & f_tissue & f_age
            
            if any(f):
                d = df_counts.loc[:, f]
                d = d.median(1).to_frame('median')
                d.loc[:, 'tissue'] = tissue
                d.loc[:, 'pfu'] = pfu
                d.loc[:, 'age'] = age
                d = d.reset_index()

                agg.append(d)
                
df_median_counts = pd.concat(agg)
# Out:
# CPU times: user 1.05 s, sys: 128 ms, total: 1.17 s
# Wall time: 1.18 s

# %%
import glob

# %%
p = inout.get_internal_path(
    'dynamic/tstoeger/181022_inclusive_any_detected/DE/Flu/*.csv')
d = glob.glob(p)

files_to_process = pd.DataFrame(columns=['path'], data = d)
files_to_process['base_name'] = files_to_process['path'].str.extract('.*/(.*).csv', expand=False)
files_to_process[['tissue', 'pfu', 'dividend', 'divisor']] = files_to_process['base_name'].str.extract(
    '^(.*)_pfu_(.*)_ages_(.*) (.*)_DE', expand=False)
files_to_process = files_to_process.set_index('base_name', verify_integrity=True)

agg = []
for j, v in files_to_process.iterrows():
    
    df = pd.read_csv(v['path'], usecols=['Symbol', 'log2FoldChange', 'pvalue', 'padj'])
    tags = ['tissue', 'pfu', 'dividend', 'divisor']
    for tag in tags:
        df.loc[:, tag] = v[tag]

    agg.append(df)

# %%
df = pd.concat(agg, axis=0)
df = df.rename(columns={'Symbol': 'gene_ensembl'})

for x in ['pfu', 'dividend', 'divisor']:
    df.loc[:, x] = df.loc[:, x].apply(float)

# %%
# Add ncbi gene IDs
df = pd.merge(
    df,
    df_genes[['gene_ensembl', 'gene_ncbi']], how='left').set_index('gene_ncbi').reset_index()

# %% [markdown]
# # Add some sanity checks and manually check discrepancies

# %%
df.loc[:, 'oldest'] = df.loc[:, ['dividend', 'divisor']].max(1)
df.loc[:, 'youngest'] = df.loc[:, ['dividend', 'divisor']].min(1)

# %%
for e in ['dividend', 'divisor', 'oldest', 'youngest']:
    df = pd.merge(
        df, 
        df_median_counts.rename(columns={'median': 'median_{}'.format(e)}), 
        left_on=['gene_ncbi', 'tissue', 'pfu', e],
        right_on=['gene_ncbi', 'tissue', 'pfu', 'age'],
        how='left'
    ).drop('age', 1)

# %%
f = df['dividend'] > df['divisor']

# %%
df.loc[f, 'o_over_y'] = df.loc[f, 'log2FoldChange']
df.loc[~f, 'o_over_y'] = -df.loc[~f, 'log2FoldChange']

# %%
test_dummy = df[(df['padj']<0.05) & ~(df['median_oldest'] == df['median_youngest'])]

# %%
f = test_dummy['median_oldest'] > test_dummy['median_youngest']
h = test_dummy[f]

# %%
h[h['o_over_y']<0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue  pfu
# AM      0.0      14
#         10.0      1
#         150.0     4
# AT2     10.0      2
# Heart   0.0      67
# WAT     0.0       2
# dtype: int64

# %%
h[h['o_over_y']>0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue      pfu
# AM          0.0       533
#             10.0       16
#             150.0     236
# AT2         0.0       241
#             10.0      502
#             150.0      38
# Adrenal     0.0      1986
# BAT         0.0       392
# Blood       0.0       180
#             10.0      414
#             150.0      79
# Brain       0.0         3
# Cerebellum  0.0        60
# Esophagus   0.0       202
# GutEP       0.0       139
# Heart       0.0         4
# Kidney      0.0      5717
# LI          0.0       122
# Liver       0.0        40
# Lung        0.0       189
#             10.0       45
#             150.0      14
# MoDC        0.0        26
#             10.0       16
#             150.0     104
# MuscSat     0.0        38
# SI          0.0       563
# Skin        0.0        21
# Stomach     0.0       946
# WAT         0.0       828
# dtype: int64

# %%
h[h['o_over_y']<0]
# Out:
#          gene_ncbi        gene_ensembl  log2FoldChange        pvalue  \
# 19787      67488.0  ENSMUSG00000023055       -0.741014  4.788168e-05
# 19801      12642.0  ENSMUSG00000050370       -1.006915  2.637548e-04
# 979204    231506.0  ENSMUSG00000035310       -0.881801  1.008081e-03
# 979206    107823.0  ENSMUSG00000057406       -0.570564  9.978300e-04
# 1415169   244667.0  ENSMUSG00000043051       -3.860493  3.184160e-04
# 1774150   235048.0  ENSMUSG00000062794       -5.227847  3.241771e-05
# 1774173   100986.0  ENSMUSG00000040407       -0.844179  4.114675e-04
# 2374820    71886.0  ENSMUSG00000028396        1.322954  2.802583e-08
# 2374821    17105.0  ENSMUSG00000069516        0.945248  2.138327e-05
# 2374822    18158.0  ENSMUSG00000029019        1.067486  7.580457e-05
# 2374823    20042.0  ENSMUSG00000061983        1.016266  9.628666e-05
# 2374825    68250.0  ENSMUSG00000032381        1.002776  1.164263e-04
# 2374826   109019.0  ENSMUSG00000026107        0.785195  1.554809e-04
# 2374827    66148.0  ENSMUSG00000022013        0.992086  2.478511e-04
# 2374828   102791.0  ENSMUSG00000039461        0.901472  3.128338e-04
# 2374829    55950.0  ENSMUSG00000047843        0.793052  4.180831e-04
# 2374831    20363.0  ENSMUSG00000064373        0.792841  4.291907e-04
# 2374832    12176.0  ENSMUSG00000078566        0.743346  4.136930e-04
# 2374833    19241.0  ENSMUSG00000049775        0.659776  5.226922e-04
# 2374834    68028.0  ENSMUSG00000039221        1.109856  5.839208e-04
# 2374835    12846.0  ENSMUSG00000000326        0.642821  6.077347e-04
# 2374836    70544.0  ENSMUSG00000004945        0.881751  6.507653e-04
# 2374837   625249.0  ENSMUSG00000075706        0.838445  7.176523e-04
# 2374838   235459.0  ENSMUSG00000033543        1.018595  7.781515e-04
# 2374839    70257.0  ENSMUSG00000021290        0.807617  8.401030e-04
# 3858072        32.019608       26.869314      32.019608        26.869314
# 3858078        45.364241       43.472756      45.364241        43.472756
# 3858081        52.476784       51.691882      52.476784        51.691882
# 4764906         5.154313        4.582718       5.154313         4.582718
# 5425047         4.942073        3.290840       4.942073         3.290840
# 5425081         3.294715        1.645420       3.294715         1.645420
# 5621050         1.612216        1.218997       1.612216         1.218997
# 5663822         8.958247        8.442370       8.958247         8.442370
# 5773467         1.311694        1.218997       1.311694         1.218997
#
#          o_over_y
# 19787   -0.741014
# 19801   -1.006915
# 979204  -0.881801
# 979206  -0.570564
# 1415169 -3.860493
# 1774150 -5.227847
# 1774173 -0.844179
# 2374820 -1.322954
# 2374821 -0.945248
# 2374822 -1.067486
# 2374823 -1.016266
# 2374825 -1.002776
# 2374826 -0.785195
# 2374827 -0.992086
# 2374828 -0.901472
# 2374829 -0.793052
# 2374831 -0.792841
# 2374832 -0.743346
# 2374833 -0.659776
# 2374834 -1.109856
# 2374835 -0.642821
# 2374836 -0.881751
# 2374837 -0.838445
# 2374838 -1.018595
# 2374839 -0.807617
# 2374840 -0.851325
# 2374841 -1.096896
# 2374842 -0.719987
# 2374844 -0.852133
# 2374845 -0.839778
# ...           ...
# 2374877 -0.775051
# 2374878 -0.868819
# 2374879 -0.874596
# 2374880 -0.671705
# 2374881 -0.615884
# 2374882 -1.082909
# 2374883 -0.602666
# 2374884 -0.619119
# 2374885 -0.647979
# 2374886 -0.615306
# 2374887 -0.610732
# 2374888 -0.744088
# 2374889 -0.558401
# 2374890 -0.684659
# 2722974 -1.156823
# 3857995 -0.782726
# 3858004 -0.762330
# 3858029 -0.445329
# 3858035 -1.352226
# 3858045 -1.617675
# 3858057 -0.394345
# 3858072 -0.857376
# 3858078 -0.697088
# 3858081 -0.640096
# 4764906 -5.467417
# 5425047 -0.689823
# 5425081 -3.936300
# 5621050 -6.350430
# 5663822 -3.071656
# 5773467 -6.775411
#
# [90 rows x 16 columns]

# %%
f = test_dummy['median_oldest'] < test_dummy['median_youngest']
h = test_dummy[f]

# %%
h[h['o_over_y']<0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue      pfu
# AM          0.0       251
#             10.0        5
#             150.0     117
# AT2         0.0       215
#             10.0      402
#             150.0      16
# Adrenal     0.0      1403
# BAT         0.0       224
# Blood       0.0        49
#             10.0      103
#             150.0     108
# Brain       0.0         8
# Cerebellum  0.0         3
# Esophagus   0.0       178
# GutEP       0.0       246
# Heart       0.0         2
# Kidney      0.0      5275
# LI          0.0       154
# Liver       0.0        13
# Lung        0.0       228
#             10.0       50
#             150.0       8
# MoDC        0.0         7
#             10.0        9
#             150.0      88
# MuscSat     0.0        18
# SI          0.0       250
# Skin        0.0        34
# Stomach     0.0       601
# WAT         0.0       752
# dtype: int64

# %%
h[h['o_over_y']>0].groupby(['tissue', 'pfu']).size()
# Out:
# tissue  pfu
# AM      0.0       17
#         150.0      2
# Heart   0.0      130
# Kidney  0.0        2
# dtype: int64

# %% [markdown]
# # Finally: export

# %%
p = inout.get_internal_path('datasets/tstoeger/181024_pooled_differential_expression_inclusive_de_any_detected/age_groups.csv.gz')
inout.ensure_presence_of_directory(p)
df.to_csv(p, compression='gzip', index=False)
